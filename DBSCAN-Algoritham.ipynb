# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

# %%
#problem: Imagine you are working for an e commerce company and the marketing want to taget the customer more effectively by creting segments based on
#their purchasing behvaiour however traditioanl segments based on the purchasing behvaiours ,however traditional segments method are providing satisfactory result
#Soloution:(Density based special clusttering of application with noise)
#Use DBSCAN to identify cluster forrr customer with smiliar purchasing pattren.

# %%
np.random.seed(42)
data=np.random.rand(100,2)

# %%
scalar=StandardScaler()

# %%
scaled_data=scalar.fit_transform(data)
scaled_data=pd.DataFrame(scaled_data,columns=["featur1","Feature2"])
scaled_data=np.round(scaled_data,2)

# %%
dbscan=DBSCAN(eps=0.3,min_samples=5)                #maximum distance between 2 sample

# %%
sns.scatterplot(data=scaled_data)
# Out:
# <Axes: >
